# %%
#importing libraries
#Web Scraping with selenium

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains

#time
import time

# %%
PATH= 'C:\Program Files (x86)\chromedriver.exe'

link = 'https://www.carrefour.com.ar/'

s = Service(PATH)

driver = webdriver.Chrome(service=s)

driver.get(link)
time.sleep(15)
#driver.implicitly_wait(10)
consent_button = driver.find_element(By.ID,'onetrust-accept-btn-handler')
consent_button.click()
time.sleep(5)

#select barra
barra = driver.find_element(By.CSS_SELECTOR, '.vtex-store-drawer-0-x-openIconContainer--menuCategory').click()


#select the iframe
iframe = driver.find_element(
    By.CSS_SELECTOR,'div.vtex-store-drawer-0-x-drawerContent.vtex-store-drawer-0-x-drawerContent--menuCategory.overflow-y-auto')

actions=ActionChains(driver)
actions.move_to_element(iframe)

time.sleep(4)
menu=driver.find_element(By.CLASS_NAME,'vtex-menu-2-x-styledLinkContent.vtex-menu-2-x-styledLinkContent--MenuCategoryFirstItem')

menu.click()

time.sleep(3)   

submenu = driver.find_element(By.LINK_TEXT,'div.vtex-menu-2-x-styledLinkContainer--MenuCategorySecondItem-hasSubmenu')

submenu.click()

#indice= driver.find_element(By.XPATH,"//button[@value='1']")
#indice=driver.find_element(By.CSS_SELECTOR,"button[value='1']")

indice = driver.find_element(By.XPATH,"//div[@class='lyracons-search-result-1-x-paginationButtonPages lyracons-search-result-1-x-paginationButtonActive mr3 flex justify-center']/button")
#indice=driver.find_element(By.XPATH,'//div[contains(text(),"1")]')
#indice = driver.find_element(By.XPATH,"//div[@class='vtex-button__label' and text()='1']")
#element = driver.find_element(By.XPATH, "//div[contains(@class, 'vtex-button__label') and text()='1']")
#driver.execute_script("arguments[0].scrollIntoView();", element)
#driver.execute_script("arguments[0].scrollIntoView();", indice)
actions.move_to_element(indice)

time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[19], line 34
#      30 menu.click()
#      32 time.sleep(3)
# ---> 34 submenu = driver.find_element(By.LINK_TEXT,'div.vtex-menu-2-x-styledLinkContainer--MenuCategorySecondItem-hasSubmenu')
#      36 submenu.click()
#      38 #indice= driver.find_element(By.XPATH,"//button[@value='1']")
#      39 #indice=driver.find_element(By.CSS_SELECTOR,"button[value='1']")
#
# File c:\Users\LENOVO\Desktop\programacion\mercado_project\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\LENOVO\Desktop\programacion\mercado_project\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\LENOVO\Desktop\programacion\mercado_project\.venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"div.vtex-menu-2-x-styledLinkContainer--MenuCategorySecondItem-hasSubmenu"}
#   (Session info: chrome=110.0.5481.177)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x012137D3]
# 	(No symbol) [0x011A8B81]
# 	(No symbol) [0x010AB36D]
# 	(No symbol) [0x010DD382]
# 	(No symbol) [0x010DD4BB]
# 	(No symbol) [0x01113302]
# 	(No symbol) [0x010FB464]
# 	(No symbol) [0x01111215]
# 	(No symbol) [0x010FB216]
# 	(No symbol) [0x010D0D97]
# 	(No symbol) [0x010D253D]
# 	GetHandleVerifier [0x0148ABF2+2510930]
# 	GetHandleVerifier [0x014B8EC1+2700065]
# 	GetHandleVerifier [0x014BC86C+2714828]
# 	GetHandleVerifier [0x012C3480+645344]
# 	(No symbol) [0x011B0FD2]
# 	(No symbol) [0x011B6C68]
# 	(No symbol) [0x011B6D4B]
# 	(No symbol) [0x011C0D6B]
# 	BaseThreadInitThunk [0x768300F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77997BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77997B8E+238]

# %%
PATH= 'C:\Program Files (x86)\chromedriver.exe'

link = 'https://www.carrefour.com.ar/'

s = Service(PATH)

driver = webdriver.Chrome(service=s)

driver.get(link)
time.sleep(15)
#driver.implicitly_wait(10)
consent_button = driver.find_element(By.ID,'onetrust-accept-btn-handler')
consent_button.click()
time.sleep(5)

#left bar click
#barra = driver.find_element(By.CSS_SELECTOR, '.vtex-store-drawer-0-x-openIconContainer--menuCategory').click()

#select barra
barra = driver.find_element(By.CSS_SELECTOR, '.vtex-store-drawer-0-x-openIconContainer--menuCategory').click()


#select the iframe
iframe = driver.find_element(
    By.CSS_SELECTOR,'div.vtex-store-drawer-0-x-drawerContent.vtex-store-drawer-0-x-drawerContent--menuCategory.overflow-y-auto')

actions=ActionChains(driver)
actions.move_to_element(iframe)

####

#for num in range(0,15):
#  driver.execute_script(f"window.document.getElementsByClassName('vtex-menu-2-x-styledLinkContent--MenuCategoryFirstItem')[{num}].style.height='30px';")

######

def select_all():
    pass


menu=driver.find_elements(By.CLASS_NAME,'vtex-menu-2-x-styledLinkContent.vtex-menu-2-x-styledLinkContent--MenuCategoryFirstItem')

for categories in menu:
    categories.click()
    time.sleep(5)
    



#hasta acá bien



value= driver.find_element(
    By.CLASS_NAME,'vtex-menu-2-x-styledLinkContent.vtex-menu-2-x-styledLinkContent--MenuCategoryFirstItemOfertas').click()



time.sleep(5)

sub_menu=driver.find_element(
    By.CSS_SELECTOR,"div.vtex-menu-2-x-styledLinkContainer.vtex-menu-2-x-styledLinkContainer--MenuCategorySecondItem-hasSubmenu")

sub_menu.click()


time.sleep(15)

pages = driver.find_element(By.CSS_SELECTOR,'div.vtex-flex-layout-0-x')

actions.move_to_element(pages).perform()

#mh6 pv2


driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 10
#       7 driver = webdriver.Chrome(service=s)
#       9 driver.get(link)
# ---> 10 time.sleep(15)
#      11 #driver.implicitly_wait(10)
#      12 consent_button = driver.find_element(By.ID,'onetrust-accept-btn-handler')
#
# KeyboardInterrupt:
